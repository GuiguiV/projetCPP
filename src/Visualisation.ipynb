# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation

# %%
with open("out_expl.txt") as file:
    lines = file.readlines()
    N_etapes = len(lines)
    array = [line.split(" ")[:-1] for line in lines]
    taille_portion = len(array[0])
    heat = np.array(array).astype(np.float)
    print(heat.shape)
# Out:
# (50, 10)

# %%
# %matplotlib notebook
fig, ax = plt.subplots()
line, = ax.plot(heat[0])
ax.set_ylabel("T")
ax.set_xlabel("x")


def animate(t):
    line.set_ydata(heat[t])
    ax.set_title("Euler explicite : t : "+str(t))
    return line,
ani = animation.FuncAnimation(fig, animate, interval=20, blit=True, repeat=True, save_count=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
with open("out_impl.txt") as file_impl:
    lines_impl = file_impl.readlines()
    N_etapes_impl = len(lines_impl)
    array_impl = [line.split(" ")[:-1] for line in lines_impl]
    taille_portion = len(array[0])
    heat_impl = np.array(array_impl).astype(np.float)
    print(heat_impl.shape)
# Out:
# (50, 10)

# %%
# %matplotlib notebook
fig, ax = plt.subplots()
line_impl, = ax.plot(heat_impl[0])
ax.set_title("Euler implicite : t = 0")
ax.set_ylabel("T")
ax.set_xlabel("x")

def animate_impl(t):
    line_impl.set_ydata(heat_impl[t])
    ax.set_title("t : "+str(t))
    return line_impl,
ani = animation.FuncAnimation(fig, animate_impl, interval=20, blit=True, save_count=50)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
